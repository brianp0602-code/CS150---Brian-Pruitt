# %% [markdown]
# # Brian Pruitt-markdown practice

# %% [markdown]
# ### I am a sophmore communications major at Bellarmine and I have interest in this class because I want to see if Business Analytics is something I'm interested in, hence the class.

# %% [markdown]
# * Programming Assignments
# * Quizzes
# * Attendance in-class participation
# * Midterm Exam
# * project

# %% [markdown]
# 1. Module 1
# 2. Module 2
# 3. Module 3
# 4. Module 4
# 5. Module 5
# 6. Module 6
# 7. Module 7
# 8. module 8
# 9. Module 9
# 10. Module 10

# %% [markdown]
# **Python**

# %% [markdown]
# *Jupyter Notebook*

# %% [markdown]
# Today I spent time `doing homework` before relaxing

# %% [markdown]
# My GitHub: [Click here] (https://github.com/brianp0602-code/CS150---Brian-Pruitt/tree/main)

# %% [markdown]
# ![University Logo](https://www.bing.com/th/id/OIP.3zkW8UwwTo6ZSYM9JiuKhAHaEK?w=284&h=211&c=8&rs=1&qlt=90&o=6&dpr=1.5&pid=3.1&rm=2)

# %% [markdown]
# In this Markdown practice, I learned how to format text using several essential Markdown features. I practiced creating headers, writing introductions, and organizing information using both bulleted and numbered lists. I also learned how to emphasize text with bold and italics, highlight phrases using backticks, and insert hyperlinks to external websites such as my GitHub profile. In addition, I practiced displaying images within a Jupyter Notebook by linking to an online logo. Overall, this assignment helped me become more comfortable using Markdown to structure and present information clearly in a .ipynb file.
