# %% [markdown]
# # My First Program
# ## This is a Markdown procatice
# 1. item 1
# 2. item 2
#
# * *item 1*
# * **item 2*

# %%
This is a blockquit
# Out:
#   Cell In[1], line 1
#     This is a blockquit
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![Python Logo](image.png)
