# %% [markdown]
# **Creating A Basic Program and Submitting to GitHub**
# ***Brian Pruitt***
# **Spring 2026**

# %% [markdown]
# Task 1: personal information

# %%
my_list= 'Brian', '20', '65', 'blue'
print ("my name is "+my_list[0]+ ", I am "+my_list[1]+ ", I am " +my_list[2]+ "cm tall, and my favorite color is"+ my_list[3])
# Out:
# my name is Brian, I am 20, I am 65cm tall, and my favorite color isblue

# %% [markdown]
# Task 2: distance conversation

# %%
miles = float(input("Enter miles: "))
km = miles * 1.60934
print(f"{miles} miles = {km:.2f} km")
# Out:
# Enter miles:  5
# 5.0 miles = 8.05 km

# %% [markdown]
# task 3:working with running times:

# %%
run1=20;run2=15
print(run1 + run2)
print(run1 - run2)
print(run2 * 2)
print((run1 + run2) / 2)
# Out:
# 35
# 5
# 30
# 17.5

# %% [markdown]
# task 4: string manipulation

# %%
quote = "   The only limit to our realization of tomorrow is our doubts of today."
print(len(quote))
print(quote.upper())
print(quote.lower())
print(quote.strip())
print(quote.split())
# Out:
# 72
#    THE ONLY LIMIT TO OUR REALIZATION OF TOMORROW IS OUR DOUBTS OF TODAY.
#    the only limit to our realization of tomorrow is our doubts of today.
# The only limit to our realization of tomorrow is our doubts of today.
# ['The', 'only', 'limit', 'to', 'our', 'realization', 'of', 'tomorrow', 'is', 'our', 'doubts', 'of', 'today.']

# %% [markdown]
# task 5: user input and operations

# %%
a = float(input("Enter side a: "))
b = float(input("Enter side b: "))
c = (a**2 + b**2)**0.5
print(f"The hypotenuse of your triangle is {round(c, 2)} units.")
# Out:
# Enter side a:  5
# Enter side b:  5
# The hypotenuse of your triangle is 7.07 units.
